# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/test_csv1.csv',encoding='euc-kr',sep=',')

# %%
df.head()
# Out:
#        사용일자  노선명     역명  승차총승객수  하차총승객수      등록일자
# 0  20230101  경강선    곤지암    1450    1539  20230104
# 1  20230101  2호선    신도림   20210   21037  20230104
# 2  20230101  2호선     문래    5995    6567  20230104
# 3  20230101  2호선  영등포구청    5629    6117  20230104
# 4  20230101  2호선     당산    6821    7594  20230104

# %%
type(df.iloc[1,0])
# Out:
# numpy.int64

# %%
# 원하는 날짜 선택하는 방법
df2 = df[df['사용일자'] == 20230101].copy()
df2.head(120).tail(30)
# Out:
#          사용일자  노선명            역명  승차총승객수  하차총승객수      등록일자
# 90   20230101  2호선           신대방   12598   13518  20230104
# 91   20230101  2호선       구로디지털단지   20191   21323  20230104
# 92   20230101  2호선      대림(구로구청)   13744   14553  20230104
# 93   20230101  3호선            옥수    4181    4397  20230104
# 94   20230101  3호선           압구정   10452   10987  20230104
# 95   20230101  3호선            신사    9949    9492  20230104
# 96   20230101  3호선            잠원    1796    1958  20230104
# 97   20230101  3호선         고속터미널   37312   28175  20230104
# 98   20230101  3호선    교대(법원.검찰청)    3104    2032  20230104
# 99   20230101  3호선  남부터미널(예술의전당)   12350   11973  20230104
# 100  20230101  3호선      양재(서초구청)   10337   12326  20230104
# 101  20230101  3호선            매봉    3235    3338  20230104
# 102  20230101  3호선            도곡    1399    1479  20230104
# 103  20230101  3호선            대치    5513    4911  20230104
# 104  20230101  3호선           학여울     614     590  20230104
# ...

# %%
# 원하는 기간 선택하는 방법 ex)1월1일에서 1월5일 사이의 데이터
df3 = df[(df['사용일자'] >= 20230101) & (df['사용일자'] < 20230106)].copy()
df3.tail()
# Out:
#           사용일자  노선명        역명  승차총승객수  하차총승객수      등록일자
# 3026  20230105  2호선  대림(구로구청)   24732   25146  20230108
# 3027  20230105  2호선       신도림   51289   50137  20230108
# 3028  20230105  2호선        문래   23533   23869  20230108
# 3029  20230105  2호선     영등포구청   23559   24320  20230108
# 3030  20230105  2호선        합정   32640   35409  20230108

# %%
# 등록일자는 삭제해도 ㄱㅊ

# %%
# push test
