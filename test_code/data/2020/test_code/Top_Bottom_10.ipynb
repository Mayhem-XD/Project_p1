# %%
import pandas as pd

# %%
df = pd.read_csv('../main_code_test/data/merged_lines.csv')
df.head()
# Out:
#       사용월  호선명     지하철역  출근시간 승차인원  출근시간 하차인원  09-16시 승차인원  09-16시 하차인원
# 0  201501  1호선       가능      68085      23287       107211        78322  \
# 1  201501  1호선  가산디지털단지      44112     230457       126462       211885
# 2  201501  1호선       간석      62525      15467        87671        65101
# 3  201501  1호선       개봉     217770      52104       311990       228238
# 4  201501  1호선       관악      83780      22169       114033        94913
#
#    퇴근시간 승차인원  퇴근시간 하차인원  새벽 승차인원  새벽 하차인원  야간 승차인원  야간 하차인원  총 승차인원  총 하차인원
# 0      31775      60948     8225     1240    17566    55647  232862  219444
# 1     209852      86319     8884     1544   114317    58461  503627  588666
# 2      28721      55488     5554     1282    17595    56137  202066  193475
# 3      90855     217153    15614     3593    50829   184806  687058  685894
# 4      40644      65829     6103     1307    19637    61074  264197  245292

# %%
df['총 승하차인원'] = df['총 승차인원'] + df['총 하차인원']
df.head()
# Out:
#       사용월  호선명     지하철역  출근시간 승차인원  출근시간 하차인원  09-16시 승차인원  09-16시 하차인원
# 0  201501  1호선       가능      68085      23287       107211        78322  \
# 1  201501  1호선  가산디지털단지      44112     230457       126462       211885
# 2  201501  1호선       간석      62525      15467        87671        65101
# 3  201501  1호선       개봉     217770      52104       311990       228238
# 4  201501  1호선       관악      83780      22169       114033        94913
#
#    퇴근시간 승차인원  퇴근시간 하차인원  새벽 승차인원  새벽 하차인원  야간 승차인원  야간 하차인원  총 승차인원  총 하차인원
# 0      31775      60948     8225     1240    17566    55647  232862  219444  \
# 1     209852      86319     8884     1544   114317    58461  503627  588666
# 2      28721      55488     5554     1282    17595    56137  202066  193475
# 3      90855     217153    15614     3593    50829   184806  687058  685894
# 4      40644      65829     6103     1307    19637    61074  264197  245292
#
#    총 승하차인원
# 0   452306
# 1  1092293
# 2   395541
# 3  1372952
# 4   509489

# %%
df.shape
# Out:
# (54404, 16)

# %% [markdown]
# ##### 2020년 1월 출근시간 승차인원 Bottom 10

# %%
df1 = df[df['사용월']==202001].copy()
df1.head()
# Out:
#          사용월  호선명     지하철역  출근시간 승차인원  출근시간 하차인원  09-16시 승차인원  09-16시 하차인원
# 6159  202001  1호선       가능      56357      20172        89483        67609  \
# 6160  202001  1호선  가산디지털단지      35516     219214       124066       217803
# 6161  202001  1호선       간석      57483      13584        81938        62378
# 6162  202001  1호선       개봉     210654      52016       305062       220798
# 6163  202001  1호선       관악      76892      19922       101170        77997
#
#       퇴근시간 승차인원  퇴근시간 하차인원  새벽 승차인원  새벽 하차인원  야간 승차인원  야간 하차인원  총 승차인원
# 6159      27911      54837     7549     1474    13877    41096  195177  \
# 6160     227483      76160     8823     2280    79966    46212  475854
# 6161      25684      53366     5317     1181    14300    44392  184722
# 6162      92211     228471    17465     5018    48389   163596  673781
# 6163      32942      64763     6786     1484    14707    49292  232497
#
#       총 하차인원  총 승하차인원
# 6159  185188   380365
# 6160  561669  1037523
# ...

# %%
df1.shape
# Out:
# (550, 16)

# %%
df1.drop(columns=['호선명'], inplace=True)
df1.head()
# Out:
#          사용월     지하철역  출근시간 승차인원  출근시간 하차인원  09-16시 승차인원  09-16시 하차인원
# 6159  202001       가능      56357      20172        89483        67609  \
# 6160  202001  가산디지털단지      35516     219214       124066       217803
# 6161  202001       간석      57483      13584        81938        62378
# 6162  202001       개봉     210654      52016       305062       220798
# 6163  202001       관악      76892      19922       101170        77997
#
#       퇴근시간 승차인원  퇴근시간 하차인원  새벽 승차인원  새벽 하차인원  야간 승차인원  야간 하차인원  총 승차인원
# 6159      27911      54837     7549     1474    13877    41096  195177  \
# 6160     227483      76160     8823     2280    79966    46212  475854
# 6161      25684      53366     5317     1181    14300    44392  184722
# 6162      92211     228471    17465     5018    48389   163596  673781
# 6163      32942      64763     6786     1484    14707    49292  232497
#
#       총 하차인원  총 승하차인원
# 6159  185188   380365
# 6160  561669  1037523
# 6161  174901   359623
# 6162  669899  1343680
# ...

# %%
df1.drop(columns=['사용월'], inplace=True)
df1.head()
# Out:
#          지하철역  출근시간 승차인원  출근시간 하차인원  09-16시 승차인원  09-16시 하차인원  퇴근시간 승차인원
# 6159       가능      56357      20172        89483        67609      27911  \
# 6160  가산디지털단지      35516     219214       124066       217803     227483
# 6161       간석      57483      13584        81938        62378      25684
# 6162       개봉     210654      52016       305062       220798      92211
# 6163       관악      76892      19922       101170        77997      32942
#
#       퇴근시간 하차인원  새벽 승차인원  새벽 하차인원  야간 승차인원  야간 하차인원  총 승차인원  총 하차인원  총 승하차인원
# 6159      54837     7549     1474    13877    41096  195177  185188   380365
# 6160      76160     8823     2280    79966    46212  475854  561669  1037523
# 6161      53366     5317     1181    14300    44392  184722  174901   359623
# 6162     228471    17465     5018    48389   163596  673781  669899  1343680
# 6163      64763     6786     1484    14707    49292  232497  213458   445955

# %%
df1.to_csv('test.csv', index=False)

# %%
list(df1.columns)
# Out:
# ['지하철역',
#  '출근시간 승차인원',
#  '출근시간 하차인원',
#  '09-16시 승차인원',
#  '09-16시 하차인원',
#  '퇴근시간 승차인원',
#  '퇴근시간 하차인원',
#  '새벽 승차인원',
#  '새벽 하차인원',
#  '야간 승차인원',
#  '야간 하차인원',
#  '총 승차인원',
#  '총 하차인원',
#  '총 승하차인원']

# %%
cols = list(df1.columns)[0]
target = list(df1.columns)[1:]

df1.groupby(cols)[target].sum().reset_index()
df1.head()
# Out:
#          지하철역  출근시간 승차인원  출근시간 하차인원  09-16시 승차인원  09-16시 하차인원  퇴근시간 승차인원
# 6159       가능      56357      20172        89483        67609      27911  \
# 6160  가산디지털단지      35516     219214       124066       217803     227483
# 6161       간석      57483      13584        81938        62378      25684
# 6162       개봉     210654      52016       305062       220798      92211
# 6163       관악      76892      19922       101170        77997      32942
#
#       퇴근시간 하차인원  새벽 승차인원  새벽 하차인원  야간 승차인원  야간 하차인원  총 승차인원  총 하차인원  총 승하차인원
# 6159      54837     7549     1474    13877    41096  195177  185188   380365
# 6160      76160     8823     2280    79966    46212  475854  561669  1037523
# 6161      53366     5317     1181    14300    44392  184722  174901   359623
# 6162     228471    17465     5018    48389   163596  673781  669899  1343680
# 6163      64763     6786     1484    14707    49292  232497  213458   445955

# %%
df1.sort_values(by='총 승하차인원', inplace=True, ascending=False)
df1 = df1.head(10)
df1
# Out:
#           지하철역  출근시간 승차인원  출근시간 하차인원  09-16시 승차인원  09-16시 하차인원  퇴근시간 승차인원
# 13298       강남     139995     550481      1020807      1551796     896672  \
# 13340       잠실     332908     304765       949824      1109037     669847
# 13347     홍대입구     187726     159885       756998      1227964     572641
# 13325       신림     608761     118555       856732       600813     285192
# 13302  구로디지털단지     381083     349181       669938       649166     496048
# 6204        서울     151576     368317       813871       763900     571021
# 17941    고속터미널      79604     177319       799335       973727     472376
# 13314       삼성      49564     497176       515832       898407     702816
# 13324      신도림     331149     178296       662783       648346     354842
# 6228       영등포     115325     216520       547513       793689     433368
#
#        퇴근시간 하차인원  새벽 승차인원  새벽 하차인원  야간 승차인원  야간 하차인원   총 승차인원   총 하차인원
# 13298     651218    17366    12742   882110   254438  2956950  3020675  \
# ...

# %%
# 시각화
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df1.plot.bar(x='지하철역', y='총 승하차인원', rot=0)
plt.title('출근시간 승차인원 Bottom 10')
# Out:
# Text(0.5, 1.0, '출근시간 승차인원 Bottom 10')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../main_code_test/data/merged_lines.csv')
df['총 승하차인원'] = df['총 승차인원'] + df['총 하차인원']

# 사용일자 선택
# df1 = df[df['사용월']==202001].copy()
df1 = df[(df['사용월'] >= 202301)&(df['사용월'] <= 202304)].copy()

df1.drop(columns=['호선명','사용월'], inplace=True)
cols = list(df1.columns)[:1]
target = list(df1.columns)[1:]
df1 = df1.groupby(cols)[target].agg('sum').reset_index()

# 표시할 컬럼 선택
df1.sort_values(by='총 하차인원', inplace=True)

# top10
# df1 = df1.head(15)
df1 = df1.iloc[2:,:]

plt.rcParams['font.family'] = 'Malgun Gothic'

colors = sns.color_palette()
df1.plot.barh('지하철역', '총 하차인원', color=colors)
plt.title('23년 총 하차인원 하위15')
plt.savefig('data/graph/2023년도 총 하차인원 하위15.png')
