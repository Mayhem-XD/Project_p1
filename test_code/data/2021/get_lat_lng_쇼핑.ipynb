# %%
import numpy as np
import pandas as pd
import requests,json,os
from urllib.parse import quote 
import os,glob

# %%
# 관광지명, 도로명주소, lat, lng, 분류
df = pd.read_excel('data/서울시 관광 쇼핑_ljh.XLSX', engine='openpyxl')
df.head(2)
# Out:
#    고유번호  언어                            상호명                         주소
# 0    64  ja            トンデムン(東大門)ショッピングタウン       100-951 ソウル市中?乙支路6街   \
# 1   193  ja  トンデムン(東大門)チャンシンドン(昌信洞)玩具??り市場  110-841 ソウル市鐘路?昌信洞 390-29
#
#                                      신주소 전화번호                        웹사이트
# 0  04564 ソウル市チュン(中)?チャンチュンダンロ253 (乙支路6街)  -40  http://www.ddm-mall.co.kr/  \
# 1   03120 ソウル市チョンノ(鐘路)?チョンロ52ギル36  (昌信洞)  -40                         NaN
#
#        운영시간                                               교통정보
# 0  店?により異なる  地下?4?線「トンデムン·ヨッサムンファゴンウォン」?1番、14番出口からすぐ 地下?4?線...
# 1  店?により異なる     地下?1?線「トンデムン」?4番出口徒?5分 地下?6?線「トンミョアプ」?6番出口徒?5分

# %%
df.to_csv('data/main/temp_files/서울_쇼핑.csv', index=False)

# %%
df = pd.read_csv('data/main/temp_files/서울_쇼핑.csv', encoding='utf-8', sep=',')
df.head(2)
# Out:
#    고유번호  언어                            상호명                         주소
# 0    64  ja            トンデムン(東大門)ショッピングタウン       100-951 ソウル市中?乙支路6街   \
# 1   193  ja  トンデムン(東大門)チャンシンドン(昌信洞)玩具??り市場  110-841 ソウル市鐘路?昌信洞 390-29
#
#                                      신주소 전화번호                        웹사이트
# 0  04564 ソウル市チュン(中)?チャンチュンダンロ253 (乙支路6街)  -40  http://www.ddm-mall.co.kr/  \
# 1   03120 ソウル市チョンノ(鐘路)?チョンロ52ギル36  (昌信洞)  -40                         NaN
#
#        운영시간                                               교통정보
# 0  店?により異なる  地下?4?線「トンデムン·ヨッサムンファゴンウォン」?1番、14番出口からすぐ 地下?4?線...
# 1  店?により異なる     地下?1?線「トンデムン」?4番出口徒?5分 地下?6?線「トンミョアプ」?6番出口徒?5分

# %%
df = df[(df['언어']) == 'ko']
df.head(4)
# Out:
#     고유번호  언어       상호명                                    주소
# 4    281  ko      통인시장              110-043 서울 종로구 통인동 10-3   \
# 5    291  ko  신사동 가로수길             135-888 서울 강남구 신사동 530 일대
# 9   1272  ko       풍월당  135-897 서울 강남구 신사동 657-37 성산빌딩 4, 5층
# 11  1770  ko  화개길 구두거리                         서울 종로구 화동 화개길
#
#                                           신주소         전화번호
# 4                    03036 서울 종로구 자하문로15길 18   02-722-0911  \
# 5                    06028 서울 강남구 압구정로 120 일대          NaN
# 9   06018 서울 강남구 도산대로53길 39 (신사동, 신사동 C/K빌딩)   02-512-2222
# 11                              서울 종로구 화동화개길        02-120
#
#                           웹사이트
# 4    http://tonginmarket.co.kr  \
# 5                          NaN
# 9   http://www.pungwoldang.kr/
# 11                         NaN
#
#                                                  운영시간
# 4   통인시장 영업시간 : 7:00 ~ 21:00 ※ 상점에 따라 상이하며, 정확한 개점...  \
# 5                                                 NaN
# 9                                12:00 ~ 20:00 (KST)
# 11                                        매장별로 차이가 있음
#
#                                                  교통정보
# 4       3호선 경복궁역 2번 출구 → 2번 출구와 3번 출구 사이 도로를 따라 직진
# 5                             3호선 신사역 8번 출구 도보 10분
# 9   3호선 압구정역 2번 출구 버스환승    7호선 강남구청역 4번 출구 버스환승   ...
# 11  3호선 경복궁 5번 출구에서 약 1.5 킬로미터 3호선 안국 1번 출구에서 약 1킬...

# %%
df.언어.unique()
# Out:
# array(['ko'], dtype=object)

# %%
## 도로명주소 불안정 -> 주소도 같이 남김
df.rename(columns= {'상호명':'관광지명', '신주소':'도로명주소'}, inplace=True)
df = df[['관광지명', '도로명주소', '주소']]
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#        관광지명                                      도로명주소
# 0      통인시장                   03036 서울 종로구 자하문로15길 18   \
# 1  신사동 가로수길                   06028 서울 강남구 압구정로 120 일대
# 2       풍월당  06018 서울 강남구 도산대로53길 39 (신사동, 신사동 C/K빌딩)
# 3  화개길 구두거리                              서울 종로구 화동화개길
# 4     테크노마트       05116 서울 광진구 광나루로56길 85 (구의동 546-4)
#
#                                      주소
# 0              110-043 서울 종로구 통인동 10-3
# 1             135-888 서울 강남구 신사동 530 일대
# 2  135-897 서울 강남구 신사동 657-37 성산빌딩 4, 5층
# 3                         서울 종로구 화동 화개길
# 4             143-200 서울 광진구 구의동 546-4

# %%
df.nunique()
# Out:
# 관광지명     162
# 도로명주소    160
# 주소       157
# dtype: int64

# %%
df.to_csv('data/서울_명소_주소.csv',index=False)

# %%
df1= pd.read_csv('data/서울_명소_쇼핑.csv', encoding='utf-8', sep=',')
df1
# Out:
#                           관광지명
# 0                         통인시장  \
# 1                     신사동 가로수길
# 2                          풍월당
# 3                     화개길 구두거리
# 4                        테크노마트
# ..                         ...
# 158  스타일난다 핑크 호텔 (명동 플래그십 스토어)
# 159          아모레 플래그십 스토어 (성수)
# 160                       경리단길
# 161                 명동문고 명동성당점
# 162                        고투몰
#
#                                               도로명주소
# 0                          03036 서울 종로구 자하문로15길 18   \
# 1                          06028 서울 강남구 압구정로 120 일대
# 2         06018 서울 강남구 도산대로53길 39 (신사동, 신사동 C/K빌딩)
# 3                                     서울 종로구 화동화개길
# 4              05116 서울 광진구 광나루로56길 85 (구의동 546-4)
# ..                                              ...
# 158        04536 서울 중구 명동8길 37-8 (충무로2가) 스타일난다 핑크호텔
# 159      04797 서울 성동구 아차산로11길 7 (성수동2가, (주)아세아이엔티)
# 160                     04344 서울 용산구 회나무로 일대(이태원동)
# 161           04537 서울 중구 명동길 66 (명동2가) 명동성당 지하 1층
# 162  06545 서울 서초구 신반포로 지하 200 (잠원동, 강남터미널지하쇼핑몰) 고투몰
#
#                                        주소
# 0                110-043 서울 종로구 통인동 10-3
# 1               135-888 서울 강남구 신사동 530 일대
# 2    135-897 서울 강남구 신사동 657-37 성산빌딩 4, 5층
# 3                           서울 종로구 화동 화개길
# 4               143-200 서울 광진구 구의동 546-4
# ..                                    ...
# 158                     서울 중구 충무로2가 66-2
# 159                  서울 성동구 성수동2가 277-52
# 160                    서울 용산구 이태원동 226-7
# 161                      서울 중구 명동2가 1-18
# 162                  서울 서초구 잠원동 68-17 고투몰
#
# [163 rows x 3 columns]

# %%
df1.head()
# Out:
#        관광지명                                      도로명주소
# 0      통인시장                   03036 서울 종로구 자하문로15길 18   \
# 1  신사동 가로수길                   06028 서울 강남구 압구정로 120 일대
# 2       풍월당  06018 서울 강남구 도산대로53길 39 (신사동, 신사동 C/K빌딩)
# 3  화개길 구두거리                              서울 종로구 화동화개길
# 4     테크노마트       05116 서울 광진구 광나루로56길 85 (구의동 546-4)
#
#                                      주소
# 0              110-043 서울 종로구 통인동 10-3
# 1             135-888 서울 강남구 신사동 530 일대
# 2  135-897 서울 강남구 신사동 657-37 성산빌딩 4, 5층
# 3                         서울 종로구 화동 화개길
# 4             143-200 서울 광진구 구의동 546-4

# %%
# df1['도로명주소'].str.replace('(', '',regex=False)
# df1['도로명주소']

# %%
# df1['주소'].str.replace('(', '',regex=False)
# df1['주소'][51:100]     # ( ), :, / --> 모두 없애기??

# %%
df1 = df1.to_csv('data/서울_명소_주소.csv', index=False)

# %%
####################################################################
# 위까지는 전처리
# 아래부터는 도로명주소 기반으로 좌표 구해서 추가함
####################################################################
df2 = pd.read_csv('data/서울_명소_쇼핑.csv', encoding='utf-8', sep=',')
df2.head(3)
# Out:
#        관광지명                                      도로명주소
# 0      통인시장                   03036 서울 종로구 자하문로15길 18   \
# 1  신사동 가로수길                   06028 서울 강남구 압구정로 120 일대
# 2       풍월당  06018 서울 강남구 도산대로53길 39 (신사동, 신사동 C/K빌딩)
#
#                                      주소
# 0              110-043 서울 종로구 통인동 10-3
# 1             135-888 서울 강남구 신사동 530 일대
# 2  135-897 서울 강남구 신사동 657-37 성산빌딩 4, 5층

# %%
df2.drop(columns=['주소'], inplace=True)
df2.head()
# Out:
#        관광지명                                      도로명주소
# 0      통인시장                   03036 서울 종로구 자하문로15길 18
# 1  신사동 가로수길                   06028 서울 강남구 압구정로 120 일대
# 2       풍월당  06018 서울 강남구 도산대로53길 39 (신사동, 신사동 C/K빌딩)
# 3  화개길 구두거리                              서울 종로구 화동화개길
# 4     테크노마트       05116 서울 광진구 광나루로56길 85 (구의동 546-4)

# %%
df2['관광지명'][1][:-1]
# Out:
# '신사동 가로수'

# %%
# 2 kakao API로 도로명 주소 구하는 함수
def kakao_location(place):
    with open('data/main/key/kakaoapikey.txt') as f_:
        kakao_key = f_.read()
    base_url = "https://dapi.kakao.com/v2/local/search/address.json"
    url = f'{base_url}?query={quote(place)}'
    header = {'Authorization':f'KakaoAK {kakao_key}'}
    result = requests.get(url, headers=header).json()
    lat_ = float(result['documents'][0]['y'])
    lng_ = float(result['documents'][0]['x'])
    return lat_,lng_

# %%
# 2 입력받은 데이터 프레임의 인덱스로 도로명주소 추출하는 함수
def rtn_addr(target):
    str_addr = df[df.관광지명 == target].도로명주소.values[-1]
    return str_addr.strip()

# %%
# 3 2번 함수들 사용해서 좌표추가
temp1 =[]
for i in df.index:
    try:
        target = df['관광지명'][i].strip()
        temp1.append(kakao_location(rtn_addr(target)))
    except:
        print(i, df.관광지명[i])
        
df_test = pd.DataFrame(temp1,columns=('lat','lng'))
df2 = pd.concat([df, df_test], axis=1)
# Out:
# 0 통인시장
# 1 신사동 가로수길
# 2 풍월당
# 3 화개길 구두거리
# 4 테크노마트
# 5 콴챈루거리
# 7 동묘 벼룩시장
# 8 서촌구루루
# 9 자비시주얼리
# 10 카카오프렌즈 강남 플래그십 스토어
# 11 한신옹기
# 12 서울 시내 핵심 관광지 ‘자유이용권’ <디스커버서울패스>
# 13 쌈지길
# 14 노앙(NOHANT)
# 15 아로마티카
# 16 엔터식스 패션스트릿 강남점
# 17 명동 쇼핑
# 18 인사동길
# 19 타임스퀘어
# 20 금천 관광 추천코스
# 21 종각지하쇼핑센터
# 22 종로 귀금속 거리
# 23 방학동 도깨비시장
# 24 센트럴시티
# 25 에비수
# 26 밀리오레 명동점
# 27 강남역 지하쇼핑센터
# 28 에이바이봄
# 29 젠틀몬스터 신사 플래그쉽 스토어
# 30 고투몰
# 31 증산종합시장
# 32 송리단길
# 33 제로띵스
# 34 광장시장
# 35 SMTOWN&STORE@DDP
# 36 홍대앞 예술시장 프리마켓
# 37 서울풍물시장
# 38 현대백화점 본점
# 39 아티지 (ARTAGE)
# 40 레어마켓 (Rare Market)
# 41 마이시티 상암점
# 42 송림수제화
# 43 연서시장
# 44 알맹상점
# 45 망원시장
# 46 젠틀몬스터 홍대 플래그십스토어
# 47 설화수 플래그십 스토어
# 48 망리단길
# 49 청량리 전통시장
# 50 청량리 통닭골목
# 51 신평화 패션타운
# 52 롯데백화점 본점
# 53 코엑스몰
# 54 두타(DOOTA)
# 55 IFC몰
# 56 제니하우스
# 57 삼성 딜라이트
# 58 서울약령시장
# 59 문정동 로데오거리
# 60 숭례문 수입상가
# 61 용산전자상가
# 62 명동지하쇼핑센터
# 63 에뛰드하우스
# 64 롯데 영플라자 명동점
# 65 Re:CODE
# 66 10 꼬르소 꼬모
# 67 정샘물 인스피레이션
# 68 용산전자랜드
# 69 한국관광명품점
# 70 가락몰
# 71 성수동 수제화 거리
# 72 더 피커
# 73 해방촌 신흥시장
# 74 쌍리단길
# 75 RECTO(렉토)
# 76 남대문시장
# 77 이대 패션거리
# 78 교보 핫트랙스 광화문점
# 79 청계5가 지하쇼핑센터
# 80 소공 지하쇼핑센터
# 81 청담 패션 거리
# 83 갤러리아백화점 WEST
# 84 뚝섬 아름다운 나눔장터
# 85 낙원악기상가
# 86 이마트 왕십리점
# 87 Addicted
# 89 라뷰티코아 청담 세이엇데이점
# 90 올리브영 명동 플래그십
# 91 대림중앙시장
# 92 이태원 앤틱 가구거리
# 93 제일시장
# 94 루미에르 붙임머리
# 95 디어얼스
# 96 웜그레이테일
# 97 셉틱탱크
# 98 회기역 파전골목
# 99 동대문역 창신동 완구 도매 시장
# 100 갤러리아 명품관
# 101 마리오아울렛
# 102 답십리 고미술상가
# 103 회현 중고 LP 상가
# 105 가리봉로데오
# 106 더 페이스샵
# 107 동화면세점
# 108 서초 벼룩시장
# 109 갤러리아백화점 EAST
# 110 메세나폴리스
# 111 스타일난다
# 112 핫트랙스 타임스퀘어점
# 113 엔터식스 왕십리점
# 114 제2롯데월드몰
# 115 한사토이
# 116 컬처앤네이처
# 117 신세계면세점
# 118 더현대서울
# 119 서울 중앙시장
# 120 8DIVISION(에이트디비젼)
# 121 남대문시장 갈치조림골목
# 122 동대문 종합시장
# 123 종오지하쇼핑센터
# 124 롯데마트 서울역점
# 125 회현지하쇼핑센터
# 126 독립문 영천시장
# 127 아름다운가게
# 128 이태원 거리
# 129 노량진 수산시장
# 130 숭인시장
# 132 반디네일 강남본점
# 133 어라운드더코너 가로수길점
# 134 한류 쇼핑
# 135 정샘물 플롭스
# 136 씨제이더마켓 제일제당센터점
# 137 평화시장
# 138 카카오프렌즈 홍대 플래그십 스토어
# 139 남성사계시장
# 140 공덕시장
# 141 커먼그라운드
# 142 상생상회
# 143 아더 스페이스 3.0 플래그십 스토어
# 144 남대문시장 칼국수골목
# 145 피겨앤그라운드
# 146 동대문 쇼핑타운
# 147 한류 상품
# 148 아이파크몰
# 149 아리따움
# 151 현대백화점 무역센터점
# 152 SPAO
# 153 새김소리
# 154 아시안무드
# 155 분더샵 청담
# 156 금남시장
# 157 가든파이브라이프
# 158 스타일난다 핑크 호텔 (명동 플래그십 스토어)
# 159 아모레 플래그십 스토어 (성수)
# 160 경리단길
# 161 명동문고 명동성당점
# 162 고투몰

# %%
# 검증
temp = df2['관광지명'][130]
rtn_addr(temp)
# Out:
# '142-140 서울특별시 강북구 도봉로 45 (미아동)'

# %%
df2.shape
# Out:
# (163, 5)

# %%
# 4 처리 끝난 파일 저장
df2.to_csv('data/addr_쇼핑.csv',index=False)

# %%
df_latlng = pd.read_csv('data/addr_쇼핑.csv')
df_latlng.head()
# Out:
#        관광지명                                      도로명주소
# 0      통인시장                   03036 서울 종로구 자하문로15길 18   \
# 1  신사동 가로수길                   06028 서울 강남구 압구정로 120 일대
# 2       풍월당  06018 서울 강남구 도산대로53길 39 (신사동, 신사동 C/K빌딩)
# 3  화개길 구두거리                              서울 종로구 화동화개길
# 4     테크노마트       05116 서울 광진구 광나루로56길 85 (구의동 546-4)
#
#                                      주소        lat         lng
# 0              110-043 서울 종로구 통인동 10-3   37.528055  126.861763
# 1             135-888 서울 강남구 신사동 530 일대  37.568735  127.007666
# 2  135-897 서울 강남구 신사동 657-37 성산빌딩 4, 5층  37.528475  127.040053
# 3                         서울 종로구 화동 화개길  37.532071  126.994591
# 4             143-200 서울 광진구 구의동 546-4   37.503935  127.002413

# %%
df_main = pd.read_csv('data/stn_r_addr_쇼핑.csv', encoding='ut')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_main = pd.read_csv('data/stn_r')
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/stn_r'
